# %% [markdown]
# # Auditoría de Cotizaciones - Radii
# ## Reto Técnico - Imanol Muñiz
#
# Este notebook contiene la auditoría completa del batch de 10 cotizaciones generadas por IA.

# %%
import numpy as np
import pandas as pd
import math

# Densidades de materiales (g/cm³)
DENSIDADES = {
    'Aluminum 6061': 2.70,
    'Aluminum 7075': 2.81,
    'Steel 1018': 7.85,
    'Steel 4140': 7.85,
    'Titanium': 4.43,
    'Stainless 304': 8.00,
    'Stainless 316': 8.00
}

# %%
def redondear_stock(dimensiones):
    return [math.ceil(dim / 10) * 10 for dim in dimensiones]

def calcular_peso_caja(largo, ancho, alto, densidad):
    # Redondear stock
    l_stock, a_stock, h_stock = redondear_stock([largo, ancho, alto])
    # Volumen en mm³ -> cm³
    volumen_cm3 = (l_stock * a_stock * h_stock) / 1000    
    # Peso en g -> kg
    peso_kg = (volumen_cm3 * densidad) / 1000    
    return peso_kg, l_stock, a_stock, h_stock

def calcular_peso_cilindro(diametro, longitud, densidad):
    # Redondear stock
    d_stock, l_stock = redondear_stock([diametro, longitud])
    # Radio en cm
    radio_cm = d_stock / 20  # Convertir de mm a cm y dividir por 2
    longitud_cm = l_stock / 10
    # Volumen en cm³
    volumen_cm3 = math.pi * (radio_cm ** 2) * longitud_cm
    # Peso en g -> kg
    peso_kg = (volumen_cm3 * densidad) / 1000
    return peso_kg, d_stock, l_stock

def calcular_peso_cilindro_hueco(diametro_ext, espesor_pared, longitud, densidad):
    # Redondear stock (solo el diámetro externo y longitud)
    d_ext_stock, l_stock = redondear_stock([diametro_ext, longitud])
    # Diámetro interno
    d_int = d_ext_stock - (2 * espesor_pared)
    # Radios en cm
    r_ext_cm = d_ext_stock / 20
    r_int_cm = d_int / 20
    longitud_cm = l_stock / 10
    # Volumen en cm³
    volumen_cm3 = math.pi * ((r_ext_cm ** 2) - (r_int_cm ** 2)) * longitud_cm
    # Peso en g -> kg
    peso_kg = (volumen_cm3 * densidad) / 1000
    return peso_kg, d_ext_stock, d_int, l_stock

# %% [markdown]
# ## Parte A - Detección de Errores
#
# Vamos a auditar cada cotización del batch y validar si cumplen con las reglas establecidas.

# %%
print("="*80)
print("Q1: Acme Corp - Aluminum 6061 - Caja 102 × 98 × 47 - Qty 1")
print("="*80)

# Dimensiones originales
dims_orig = [102, 98, 47]
material = 'Aluminum 6061'
densidad = DENSIDADES[material]

# Calcular peso correcto
peso_correcto, l_stock, a_stock, h_stock = calcular_peso_caja(102, 98, 47, densidad)
# Out:
# ...
# Q1: Acme Corp - Aluminum 6061 - Caja 102 × 98 × 47 - Qty 1
# ...

# %%
print("\n" + "="*80)
print("Q2: Acme Corp - Aluminum 6061 - Caja 102 × 98 × 47 - Qty 25")
print("="*80)

# Mismo material y dimensiones que Q1
peso_correcto_q2 = peso_correcto  # Ya calculado arriba
# Out:
# ...
# Q2: Acme Corp - Aluminum 6061 - Caja 102 × 98 × 47 - Qty 25
# ...

# %%
print("\n" + "="*80)
print("Q3: BetaTech - Steel 4140 - Cilindro Ø80 × 200 - Qty 5")
print("="*80)

material_q3 = 'Steel 4140'
densidad_q3 = DENSIDADES[material_q3]

# Calcular peso correcto
peso_correcto_q3, d_stock, l_stock = calcular_peso_cilindro(80, 200, densidad_q3)
# Out:
# ...
# Q3: BetaTech - Steel 4140 - Cilindro Ø80 × 200 - Qty 5
# ...

# %%
print("\n" + "="*80)
print("Q4: BetaTech - Steel 1018 - Cilindro Ø80 × 200 - Qty 5")
print("="*80)

material_q4 = 'Steel 1018'
densidad_q4 = DENSIDADES[material_q4]

# Calcular peso correcto (mismas dimensiones que Q3)
peso_correcto_q4, d_stock_q4, l_stock_q4 = calcular_peso_cilindro(80, 200, densidad_q4)
# Out:
# ...
# Q4: BetaTech - Steel 1018 - Cilindro Ø80 × 200 - Qty 5
# ...

# %%
print("\n" + "="*80)
print("Q5: CanDo Mfg - Titanium - Caja 2.0 × 2.0 × 4.0 - Qty 1")
print("="*80)

material_q5 = 'Titanium'
densidad_q5 = DENSIDADES[material_q5]
dims_mm = [2, 2, 4]

peso_correcto_q5, l_stock_q5, a_stock_q5, h_stock_q5 = calcular_peso_caja(dims_mm[0], dims_mm[1], dims_mm[2], densidad_q5)
# Out:
# ...
# Q5: CanDo Mfg - Titanium - Caja 2.0 × 2.0 × 4.0 - Qty 1
# ...

# %%
print("\n" + "="*80)
print("Q6: CanDo Mfg - Titanium - Caja 50 × 50 × 100 - Qty 20")
print("="*80)

peso_correcto_q6, l_stock_q6, a_stock_q6, h_stock_q6 = calcular_peso_caja(50, 50, 100, densidad_q5)
# Out:
# ...
# Q6: CanDo Mfg - Titanium - Caja 50 × 50 × 100 - Qty 20
# ...

# %%
print("\n" + "="*80)
print("Q7: DeltaAero - Aluminum 7075 - Caja 203 × 152 × 22 - Qty 50")
print("="*80)

material_q7 = 'Aluminum 7075'
densidad_q7 = DENSIDADES[material_q7]

peso_correcto_q7, l_stock_q7, a_stock_q7, h_stock_q7 = calcular_peso_caja(203, 152, 22, densidad_q7)
# Out:
# ...
# Q7: DeltaAero - Aluminum 7075 - Caja 203 × 152 × 22 - Qty 50
# ...

# %%
print("\n" + "="*80)
print("Q8: EastMech - Stainless 316 - Cilindro hueco Ø60 (pared 5mm) × 150 - Qty 10")
print("="*80)

material_q8 = 'Stainless 316'
densidad_q8 = DENSIDADES[material_q8]

peso_correcto_q8, d_ext_stock_q8, d_int_q8, l_stock_q8 = calcular_peso_cilindro_hueco(60, 5, 150, densidad_q8)
# Out:
# ...
# Q8: EastMech - Stainless 316 - Cilindro hueco Ø60 (pared 5mm) × 150 - Qty 10
# ...

# %%
print("\n" + "="*80)
print("Q9: EastMech - Stainless 304 - Cilindro hueco Ø60 (pared 5mm) × 150 - Qty 10")
print("="*80)

material_q9 = 'Stainless 304'
densidad_q9 = DENSIDADES[material_q9]

peso_correcto_q9, d_ext_stock_q9, d_int_q9, l_stock_q9 = calcular_peso_cilindro_hueco(60, 5, 150, densidad_q9)
# Out:
# ...
# Q9: EastMech - Stainless 304 - Cilindro hueco Ø60 (pared 5mm) × 150 - Qty 10
# ...

# %%
print("\n" + "="*80)
print("Q10: Acme Corp - Aluminum 6061 - Caja 102 × 98 × 47 - Qty 1")
print("="*80)

# Mismas dimensiones y material que Q1 y Q2
peso_correcto_q10 = peso_correcto  # Ya calculado
# Out:
# ...
# Q10: Acme Corp - Aluminum 6061 - Caja 102 × 98 × 47 - Qty 1
# ...

# %% [markdown]
# ### Resumen Consolidado de Errores
#
# Tabla de validación completa de las 10 cotizaciones.

# %%
# Crear tabla resumen
resumen = []

# Q1
resumen.append({
    'ID': 'Q1',
    'Peso_Correcto_kg': round(peso_correcto, 2),
    'Peso_IA_kg': 1.26,
    'Error_Peso': '🛑 -15%',
    'Descuento_Volumen': '—',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '—',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso bajo (no aplicó redondeo stock)',
    'Impacto económico': 'Posible pérdida en venta o margen'
})

# Q2
resumen.append({
    'ID': 'Q2',
    'Peso_Correcto_kg': round(peso_correcto_q2, 2),
    'Peso_IA_kg': 1.26,
    'Error_Peso': '🛑 -15%',
    'Descuento_Volumen': '🛑 NO (debería)',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '—',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso bajo + falta descuento volumen',
    'Impacto económico': 'Posible pérdida en venta o margen'
})

# Q3
resumen.append({
    'ID': 'Q3',
    'Peso_Correcto_kg': round(peso_correcto_q3, 2),
    'Peso_IA_kg': 2.7,
    'Error_Peso': '🛑 -66%',
    'Descuento_Volumen': '—',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '—',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso bajo',
    'Impacto económico': 'Posible pérdida en venta o margen'
})

# Q4
resumen.append({
    'ID': 'Q4',
    'Peso_Correcto_kg': round(peso_correcto_q4, 2),
    'Peso_IA_kg': 7.9,
    'Error_Peso': '✅ 0%',
    'Descuento_Volumen': '—',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '—',
    'Clasificación': '✅ CORRECTO',
    'Principal_Error': '—',
    'Impacto económico': '—'
})

# Q5
resumen.append({
    'ID': 'Q5',
    'Peso_Correcto_kg': round(peso_correcto_q5, 2),
    'Peso_IA_kg': 1.1,
    'Error_Peso': '🛑 -37%',
    'Descuento_Volumen': '—',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '⚠️ Dudoso',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso alto + dimensiones probablemente mal registradas',
    'Impacto económico': 'Posible pérdida en venta o margen'
})

# Q6
resumen.append({
    'ID': 'Q6',
    'Peso_Correcto_kg': round(peso_correcto_q6, 2),
    'Peso_IA_kg': 1.1,
    'Error_Peso': '✅ ~1%',
    'Descuento_Volumen': '⚠️ Probablemente sí',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '🛑 No aplicado (Debería)',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Precio bajo',
    'Impacto económico': 'Posible pérdida en venta o margen'
})

# Q7
resumen.append({
    'ID': 'Q7',
    'Peso_Correcto_kg': round(peso_correcto_q7, 2),
    'Peso_IA_kg': 2.1,
    'Error_Peso': '🛑 -26%',
    'Descuento_Volumen': '⚠️ Probablemente sí',
    'Premium_Urgencia': '⚠️ Probablemente no aplicado (debería)',
    'Tooling_Surcharge': '—',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso bajo + Precio muy bajo para volumen y cantidad',
    'Impacto económico': 'Posible pérdida en venta o margen'
})

# Q8
resumen.append({
    'ID': 'Q8',
    'Peso_Correcto_kg': round(peso_correcto_q8, 2),
    'Peso_IA_kg': 2.0,
    'Error_Peso': '🛑 +92%',
    'Descuento_Volumen': '⚠️ Probablemente sí',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '—',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso alto',
    'Impacto económico': 'Posible pérdida de venta por peso excesivo'
})

# Q9
resumen.append({
    'ID': 'Q9',
    'Peso_Correcto_kg': round(peso_correcto_q9, 2),
    'Peso_IA_kg': 2.0,
    'Error_Peso': '🛑 +92%',
    'Descuento_Volumen': '⚠️ Probablemente sí',
    'Premium_Urgencia': '—',
    'Tooling_Surcharge': '—',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso alto',
    'Impacto económico': 'Posible pérdida de venta por peso excesivo'
})

# Q10
resumen.append({
    'ID': 'Q10',
    'Peso_Correcto_kg': round(peso_correcto_q10, 2),
    'Peso_IA_kg': 1.26,
    'Error_Peso': '🛑 -15%',
    'Descuento_Volumen': '—',
    'Premium_Urgencia': '🛑 NO aplicado (debería)',
    'Tooling_Surcharge': '—',
    'Clasificación': '🛑 CRÍTICO',
    'Principal_Error': 'Peso bajo + Precio MENOR con urgencia en comparación con Q1 y Q2',
    'Impacto económico': 'Posible pérdida en venta o margen'
})

df_resumen = pd.DataFrame(resumen)
print("\n📊 TABLA RESUMEN DE VALIDACIÓN")
print("="*120)
df_resumen
# Out:
# 📊 TABLA RESUMEN DE VALIDACIÓN
# ...
#     ID  Peso_Correcto_kg  Peso_IA_kg Error_Peso    Descuento_Volumen  \
# 0   Q1              1.49        1.26     🛑 -15%                    —
# 1   Q2              1.49        1.26     🛑 -15%       🛑 NO (debería)
# 2   Q3              7.89        2.70     🛑 -66%                    —
# 3   Q4              7.89        7.90       ✅ 0%                    —
# 4   Q5              0.00        1.10     🛑 -37%                    —
# 5   Q6              1.11        1.10      ✅ ~1%  ⚠️ Probablemente sí
# 6   Q7              2.83        2.10     🛑 -26%  ⚠️ Probablemente sí
# 7   Q8              1.04        2.00     🛑 +92%  ⚠️ Probablemente sí
# 8   Q9              1.04        2.00     🛑 +92%  ⚠️ Probablemente sí
# 9  Q10              1.49        1.26     🛑 -15%                    —
#
#                          Premium_Urgencia        Tooling_Surcharge  \
# 0                                       —                        —
# ...

# %% [markdown]
# ### Parte A — Detección de errores (lo más importante)
#
# Para cada cotización:
# - ¿El peso es correcto? Muestra tus cálculos.
#     - Los cálculos se encuentran en el archivo Auditoría de cotizaciones.txt. Podemos observar la tabla de arriba para ver si los pesos fueron correctos
# - ¿El precio cumple las reglas de negocio?
#     - En la tabla de arriba podemos ver en resumen qué cotizaciones cumplieron cuáles reglas de negocio.
# - Clasifica cada quote: ✅ Correcto, ⚠️ Warning, 🛑 Crítico
#     - En la tabla de arriba se muestra la clasificación de cada cotización
# - Estima el impacto en dinero donde sea posible
#     - Considero que se necesita más información sobre los costos de los materiales y mano de obra para poder dar números o porcentajes especificos en el impacto económico. Únicamente se muestran posibles consecuencias de cada una de las cotizaciones.

# %% [markdown]
# ### Parte B — Análisis de patrones
#
# 1. ¿Por qué la tasa de conversión de titanio es solo 8%?
# 2. ¿Por qué los márgenes de la IA son 12% más bajos que los humanos?
#  - Los datos demuestran que el modelo tiene problemas calculando el volumen de los objetos lo que debe repercutir directamente en el precio cotizado. Adicionalmente se puede observar las cotizaciones que aplican para el descuento de +10 piezas son
# 3. ¿Qué pasó en los meses 4-6? ¿Qué le preguntarías al equipo?
